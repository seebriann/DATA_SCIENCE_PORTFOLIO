# %% [markdown]
# <a href="https://colab.research.google.com/github/seebriann/DATA_SCIENCE_PORTFOLIO/blob/main/Movie_Analytics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd # -> Module yang digunaakn untuk analisis data, editing dataframe
import numpy as np # -> Module yang digunakan untuk operasi matematika
import matplotlib.pyplot as plt # -> Module yang digunakan untuk melakukan visualisasi data
import seaborn as sns # -> Module yang digunakan untuk melakukan visualisasi data
import os # -> Untuk melakukan operasi sistem di google colab

# %%
os.chdir("gdrive/MyDrive/Materi Mentoring/Movie Analytics")

# %%
os.listdir()
# Out:
# ['Movie Analytics.ipynb',
#  'ratings_small.csv',
#  'movies_metadata.csv',
#  'Movie Analytics.gslides']

# %%
movies_data = pd.read_csv("movies_metadata.csv")

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
#  14  release_date           45376 non-null  object
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45463 non-null  bool
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: bool(2), float64(5), int64(2), object(15)
# memory usage: 7.7+ MB

# %%
movies_data.sample(10)
# Out:
#        adult                              belongs_to_collection    budget  \
# 5864    True                                                NaN         0
# 22921   True                                                NaN         0
# 42939   True                                                NaN   2000000
# 2688    True                                                NaN  45000000
# 37821   True                                                NaN         0
# 44879   True                                                NaN         0
# 3798    True  {'id': 338327, 'name': 'Beach Party Collection...         0
# 18566   True                                                NaN         0
# 40125   True                                                NaN         0
# 38542   True                                                NaN         0
#
#                                                   genres  \
# 5864   [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 22921  [{'id': 27, 'name': 'Horror'}, {'id': 53, 'nam...
# 42939                      [{'id': 18, 'name': 'Drama'}]
# 2688   [{'id': 18, 'name': 'Drama'}, {'id': 9648, 'na...
# 37821  [{'id': 18, 'name': 'Drama'}, {'id': 14, 'name...
# 44879  [{'id': 18, 'name': 'Drama'}, {'id': 10749, 'n...
# 3798   [{'id': 35, 'name': 'Comedy'}, {'id': 10402, '...
# 18566                     [{'id': 35, 'name': 'Comedy'}]
# 40125  [{'id': 18, 'name': 'Drama'}, {'id': 10769, 'n...
# 38542  [{'id': 80, 'name': 'Crime'}, {'id': 18, 'name...
#
#                                            homepage      id    imdb_id  \
# 5864                                            NaN   15395  tt0282698
# 22921            http://www.bitterfeastthefilm.com/   52817  tt1477835
# 42939                                           NaN  371899  tt3775176
# 2688                                            NaN    9944  tt0107798
# 37821                                           NaN  114242  tt0163624
# 44879  http://level33entertainment.com/1_Night.html  416691  tt4126694
# 3798                                            NaN   39113  tt0057887
# 18566                                           NaN   79940  tt1855401
# 40125                                           NaN   47325  tt1364478
# 38542                                           NaN   97481  tt3253740
#
#       original_language                       original_title  \
# 5864                 en                            Love Liza
# 22921                en                         Bitter Feast
# 42939                ru                     Синдром Петрушки
# 2688                 en                    The Pelican Brief
# 37821                de                                Faust
# 44879                en                              1 Night
# 3798                 en                         Bikini Beach
# 18566                en  Tim and Eric's Billion Dollar Movie
# 40125                en                            Casanegra
# 38542                en                       The Confession
#
#                                                 overview  ...  release_date  \
# 5864   Following the unexplained suicide of his wife ...  ...    2002-12-30
# 22921  A celebrity chef exacts revenge on a food blog...  ...    2010-07-08
# 42939  Since early childhood Peter has been obsessed ...  ...    2015-11-05
# 2688   Two Supreme Court Justices have been assassina...  ...    1993-12-16
# 37821  In 1957 Gustaf Gründgens staged a new producti...  ...    1960-09-30
# 44879  Thirty-something Elizabeth must decide whether...  ...    2017-02-10
# 3798   A millionaire sets out to prove his theory tha...  ...    1964-07-22
# 18566  Two guys get a billion dollars to make a movie...  ...    2012-03-02
# 40125  A Moroccan-Norwegian co-production about the d...  ...    2009-05-09
# 38542  A unique story of redemption and an exploratio...  ...    2011-07-01
#
#            revenue runtime                                   spoken_languages  \
# 5864           0.0    90.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 22921          0.0   105.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 42939          0.0    90.0           [{'iso_639_1': 'ru', 'name': 'Pусский'}]
# 2688   195268056.0   141.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 37821          0.0   128.0           [{'iso_639_1': 'de', 'name': 'Deutsch'}]
# 44879          0.0    76.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3798           0.0    99.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 18566          0.0    94.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 40125          0.0   131.0  [{'iso_639_1': 'ar', 'name': 'العربية'}, {'iso...
# 38542          0.0    63.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#          status                                            tagline  \
# 5864   Released                                                NaN
# 22921  Released                                                NaN
# 42939  Released  The story of an all-consuming passion between ...
# 2688   Released  Two Supreme Court Justices have been assassina...
# 37821  Released                                                NaN
# 44879  Released                       Love can happen at any time.
# 3798   Released  It's where every torso is more so, and bare-as...
# 18566  Released                                                NaN
# 40125  Released  What's white about Casablanca, they should cal...
# 38542  Released                                                NaN
#
#                                      title  video vote_average vote_count
# 5864                             Love Liza  False          6.5       25.0
# 22921                         Bitter Feast  False          5.5       17.0
# 42939                  The Puppet Syndrome  False          7.0        2.0
# 2688                     The Pelican Brief  False          6.3      377.0
# 37821                                Faust  False          7.2        6.0
# 44879                              1 Night  False          6.2       30.0
# 3798                          Bikini Beach  False          6.7       10.0
# 18566  Tim and Eric's Billion Dollar Movie  False          5.2       35.0
# 40125                            Casanegra  False          5.5        3.0
# 38542                       The Confession  False          6.7       17.0
#
# [10 rows x 24 columns]

# %%
movies_data["release_date"] = pd.to_datetime(movies_data["release_date"])

# %%
movies_data["release_date"].dtypes
# Out:
# dtype('<M8[ns]')

# %%
movies_data["status"].unique()
# Out:
# array(['Released', nan, 'Rumored', 'Post Production', 'In Production',
#        'Planned', 'Canceled'], dtype=object)

# %%
movies_data["original_language"].nunique()
# Out:
# 89

# %%
#movies_data["status"] == "Released"

# %%
movies_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 45463 entries, 0 to 45462
# Data columns (total 24 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   adult                  45463 non-null  bool
#  1   belongs_to_collection  4491 non-null   object
#  2   budget                 45463 non-null  int64
#  3   genres                 45463 non-null  object
#  4   homepage               7779 non-null   object
#  5   id                     45463 non-null  int64
#  6   imdb_id                45446 non-null  object
#  7   original_language      45452 non-null  object
#  8   original_title         45463 non-null  object
#  9   overview               44509 non-null  object
#  10  popularity             45460 non-null  float64
#  11  poster_path            45077 non-null  object
#  12  production_companies   45460 non-null  object
#  13  production_countries   45460 non-null  object
#  14  release_date           45376 non-null  datetime64[ns]
#  15  revenue                45460 non-null  float64
#  16  runtime                45203 non-null  float64
#  17  spoken_languages       45460 non-null  object
#  18  status                 45379 non-null  object
#  19  tagline                20412 non-null  object
#  20  title                  45460 non-null  object
#  21  video                  45463 non-null  bool
#  22  vote_average           45460 non-null  float64
#  23  vote_count             45460 non-null  float64
# dtypes: bool(2), datetime64[ns](1), float64(5), int64(2), object(14)
# memory usage: 7.7+ MB

# %%
movies_data.head()
# Out:
#    adult                              belongs_to_collection    budget  \
# 0   True  {'id': 10194, 'name': 'Toy Story Collection', ...  30000000
# 1   True                                                NaN  65000000
# 2   True  {'id': 119050, 'name': 'Grumpy Old Men Collect...         0
# 3   True                                                NaN  16000000
# 4   True  {'id': 96871, 'name': 'Father of the Bride Col...         0
#
#                                               genres  \
# 0  [{'id': 16, 'name': 'Animation'}, {'id': 35, '...
# 1  [{'id': 12, 'name': 'Adventure'}, {'id': 14, '...
# 2  [{'id': 10749, 'name': 'Romance'}, {'id': 35, ...
# 3  [{'id': 35, 'name': 'Comedy'}, {'id': 18, 'nam...
# 4                     [{'id': 35, 'name': 'Comedy'}]
#
#                                homepage     id    imdb_id original_language  \
# 0  http://toystory.disney.com/toy-story    862  tt0114709                en
# 1                                   NaN   8844  tt0113497                en
# 2                                   NaN  15602  tt0113228                en
# 3                                   NaN  31357  tt0114885                en
# 4                                   NaN  11862  tt0113041                en
#
#                 original_title  \
# 0                    Toy Story
# 1                      Jumanji
# 2             Grumpier Old Men
# 3            Waiting to Exhale
# 4  Father of the Bride Part II
#
#                                             overview  ...  release_date  \
# 0  Led by Woody, Andy's toys live happily in his ...  ...    1995-10-30
# 1  When siblings Judy and Peter discover an encha...  ...    1995-12-15
# 2  A family wedding reignites the ancient feud be...  ...    1995-12-22
# 3  Cheated on, mistreated and stepped on, the wom...  ...    1995-12-22
# 4  Just when George Banks has recovered from his ...  ...    1995-02-10
#
#        revenue runtime                                   spoken_languages  \
# 0  373554033.0    81.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 1  262797249.0   104.0  [{'iso_639_1': 'en', 'name': 'English'}, {'iso...
# 2          0.0   101.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 3   81452156.0   127.0           [{'iso_639_1': 'en', 'name': 'English'}]
# 4   76578911.0   106.0           [{'iso_639_1': 'en', 'name': 'English'}]
#
#      status                                            tagline  \
# 0  Released                                                NaN
# 1  Released          Roll the dice and unleash the excitement!
# 2  Released  Still Yelling. Still Fighting. Still Ready for...
# 3  Released  Friends are the people who let you be yourself...
# 4  Released  Just When His World Is Back To Normal... He's ...
#
#                          title  video vote_average vote_count
# 0                    Toy Story  False          7.7     5415.0
# 1                      Jumanji  False          6.9     2413.0
# 2             Grumpier Old Men  False          6.5       92.0
# 3            Waiting to Exhale  False          6.1       34.0
# 4  Father of the Bride Part II  False          5.7      173.0
#
# [5 rows x 24 columns]

# %%
movies_data["profit"] = movies_data["revenue"] - movies_data["budget"]

# %%
movies_data["profit"].hist(bins = 100)
plt.title("Profit Movies Distribution")
plt.show()

# %%
movies_data["profit"].describe()
# Out:
# count    4.546000e+04
# mean     6.984491e+06
# std      5.214125e+07
# min     -1.657101e+08
# 25%      0.000000e+00
# 50%      0.000000e+00
# 75%      0.000000e+00
# max      2.550965e+09
# Name: profit, dtype: float64

# %%
import seaborn as sns

# %%
movies_data["profit"].plot(kind = "box")
# Out:
# <Axes: >

# %%
sns.boxplot(data = movies_data, x = "profit")
plt.show()

# %%
sns.boxplot(data = movies_data, x = "runtime")
plt.show()

# %%
movies_data["profit"].quantile(0.9)
# Out:
# 1578210.8999999824

# %%
sns.scatterplot(data = movies_data,
                x = "runtime",
                y = "profit")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-d620a0efca9a> in <cell line: 1>()
# ----> 1 sns.scatterplot(data = movies_data,
#       2                 x = "runtime",
#       3                 y = "profit")
#       4 plt.show()
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in scatterplot(data, x, y, hue, size, style, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, legend, ax, **kwargs)
#     740
#     741     variables = _ScatterPlotter.get_semantics(locals())
# --> 742     p = _ScatterPlotter(data=data, variables=variables, legend=legend)
#     743
#     744     p.map_hue(palette=palette, order=hue_order, norm=hue_norm)
#
# /usr/local/lib/python3.10/dist-packages/seaborn/relational.py in __init__(self, data, variables, legend)
#     536         )
#     537
# --> 538         super().__init__(data=data, variables=variables)
#     539
#     540         self.legend = legend
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in __init__(self, data, variables)
#     638         # information for numeric axes would be information about log scales.
#     639         self._var_ordered = {"x": False, "y": False}  # alt., used DefaultDict
# --> 640         self.assign_variables(data, variables)
#     641
#     642         for var, cls in self._semantic_mappings.items():
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in assign_variables(self, data, variables)
#     699         else:
#     700             self.input_format = "long"
# --> 701             plot_data, variables = self._assign_variables_longform(
#     702                 data, **variables,
#     703             )
#
# /usr/local/lib/python3.10/dist-packages/seaborn/_oldcore.py in _assign_variables_longform(self, data, **kwargs)
#     936
#     937                 err = f"Could not interpret value `{val}` for parameter `{key}`"
# --> 938                 raise ValueError(err)
#     939
#     940             else:
#
# ValueError: Could not interpret value `profit` for parameter `y`

# %%
profitable_movies = movies_data[movies_data["profit"] > 0]

# %%
sns.scatterplot(data = profitable_movies,
                x = "runtime",
                y = "profit")
plt.show()

# %%
rating = pd.read_csv("ratings_small.csv")

# %%
rating_movies = rating.groupby("movieId", as_index = False)["rating"].median()

# %%
sns.histplot(data = rating_movies,
                x = "rating")
# Out:
# <Axes: xlabel='rating', ylabel='Count'>

# %%
rating_movies["good_movies"] = rating_movies["rating"] >= 3

# %%
rating_movies["good_movies"].value_counts().plot(kind = "pie")
# Out:
# <Axes: ylabel='good_movies'>

# %%
new_df = movies_data.merge(rating_movies,
                        left_on = "id",
                        right_on = "movieId",
                        how = "inner")

# %%
sns.histplot(data = new_df,
             x = "profit",
             hue = "good_movies")
# Out:
# <Axes: xlabel='profit', ylabel='Count'>

# %%
sns.scatterplot(data = new_df,
             x = "rating",
                y = "profit")
# Out:
# <Axes: xlabel='rating', ylabel='profit'>

# %%
new_df[["rating"]]
# Out:
#       rating
# 0       3.75
# 1       1.50
# 2       3.50
# 3       5.00
# 4       3.00
# ...      ...
# 1027    3.00
# 1028    4.00
# 1029    4.00
# 1030    4.00
# 1031    4.50
#
# [1032 rows x 1 columns]

# %%
new_df["original_language"].value_counts().plot(kind = "bar")
# Out:
# <Axes: >

# %%
new_df.select_dtypes(include = "number")
# Out:
#         budget     id  popularity      revenue  runtime  vote_average  \
# 0     60000000    949   17.924927  187436818.0    170.0           7.7
# 1     58000000    710   14.686036  352194034.0    130.0           6.6
# 2     98000000   1408    7.284477   10017322.0    119.0           5.7
# 3     52000000    524   10.137389  116112375.0    178.0           7.8
# 4     16500000   4584   10.673167  135000000.0    136.0           7.2
# ...        ...    ...         ...          ...      ...           ...
# 2826         0  80831    0.083371          0.0    121.0           6.5
# 2827         0   3104    2.302582          0.0     92.0           5.9
# 2828         0  64197    0.528657          0.0     97.0           6.0
# 2829         0  98604    0.803588          0.0     91.0           4.6
# 2830         0  49280    1.109068          0.0      1.0           6.5
#
#       vote_count  movieId  rating
# 0         1886.0      949    3.75
# 1         1194.0      710    1.50
# 2          137.0     1408    4.00
# 3         1343.0      524    3.50
# 4          364.0     4584    5.00
# ...          ...      ...     ...
# 2826         2.0    80831    3.25
# 2827        33.0     3104    4.00
# 2828         5.0    64197    4.00
# 2829         6.0    98604    4.00
# 2830        22.0    49280    5.00
#
# [2831 rows x 9 columns]

# %%
def select_columns(df: pd.DataFrame, features: list,  target: list = "rating"):

  df = df.dropna().reset_index(drop = True)
  X = df[features]
  y = (df[target] >= 3).astype("int")

  return X, y

# %%
from sklearn.model_selection import train_test_split

# %%
features = ["budget", "popularity", "vote_average"]
X, y = select_columns(new_df, features = features)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.3, random_state = 42)

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
minmax = MinMaxScaler()

# %%
minmax.fit(X_train)
# Out:
# MinMaxScaler()

# %%
def scaling(df, scaler):

  # df["runtime	"] = df["runtime"].div(60)

  scaled_array = scaler.transform(df)
  scaled_df = pd.DataFrame(scaled_array, columns = scaler.get_feature_names_out())

  return scaled_df

# %%
X_train_scaled = scaling(X_train, minmax)
X_test_scaled = scaling(X_test, minmax)

# %%
X_test_scaled.iloc[0]
# Out:
# budget          0.000000
# popularity      0.006914
# runtime         0.303125
# vote_average    0.300000
# Name: 0, dtype: float64

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier

# %%
knn = KNeighborsClassifier(n_neighbors = 5)
dt = DecisionTreeClassifier()

# %%
knn.fit(X_train_scaled, y_train)
dt.fit(X_train_scaled, y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_train_pred_knn = knn.predict(X_train_scaled)
y_train_pred_dt = dt.predict(X_train_scaled)

# %%
y_test_pred_knn = knn.predict(X_test_scaled)
y_test_pred_dt = dt.predict(X_test_scaled)

# %%
pd.crosstab(y_test, y_test_pred_knn)
# Out:
# col_0   0   1
# rating
# 0       0   6
# 1       1  35

# %%
pd.crosstab(y_test, y_test_pred_dt)
# Out:
# col_0   0   1
# rating
# 0       0   6
# 1       4  32
